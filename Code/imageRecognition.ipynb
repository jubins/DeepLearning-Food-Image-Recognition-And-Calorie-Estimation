# %%
import tensorflow as tf
tf.__version__
# Out:
# '0.11.0'

# %%
from IPython.display import Image
imageName = 'burger.jpg'
#imagePath = '/tensorflow/tensorflow/models/image/imagenet/testimages/'+imageName
Image(filename=imageName)

# %%
s = %run ./classify_image.py --image_file burger.jpg
# Out:
# >> Downloading inception-2015-12-05.tgz 100.0%
# Succesfully downloaded inception-2015-12-05.tgz 88931400 bytes.
# cheeseburger (score = 0.65784)
# bagel, beigel (score = 0.03673)
# French loaf (score = 0.00502)
# meat loaf, meatloaf (score = 0.00457)
# hotdog, hot dog, red hot (score = 0.00373)

# %%
print s
# Out:
# None
